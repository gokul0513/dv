# %%
import pandas as pd

# %%
import pandas as pd
a=pd.read_csv("iris3.csv")
a.head()
# Out:
#    sepel length  sepel_width  petal_length  petal_width        class
# 0           5.1          3.5           NaN          0.2  Iris-setosa
# 1           NaN          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           NaN          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
a['sepel length']=a['sepel length'].fillna(0)

# %%
a.isnull().sum()
# Out:
# sepel length    0
# sepel_width     6
# petal_length    5
# petal_width     0
# class           0
# dtype: int64

# %%
mn=a['sepel_width'].mean()
mn
# Out:
# 3.0541666666666667

# %%
a['sepel length']=a['sepel length'].fillna(mn)

# %%
a.isnull().sum()
# Out:
# sepel length    0
# sepel_width     6
# petal_length    5
# petal_width     0
# class           0
# dtype: int64

# %%
md=a['sepel_width'].mode()[0]
md
# Out:
# 3.0

# %%
a['sepel_width']=a['sepel_width'].fillna(md)

# %%
a.isnull().sum()
# Out:
# sepel length    0
# sepel_width     0
# petal_length    5
# petal_width     0
# class           0
# dtype: int64

# %%
a['petal_length']=a['petal_length'].ffill()
a['petal_width']=a['petal_width'].bfill()
a.isnull().sum()
# Out:
# sepel length    0
# sepel_width     0
# petal_length    1
# petal_width     0
# class           0
# dtype: int64
