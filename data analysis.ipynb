# %%
import pandas as pd
a=pd.read_csv("dataset1.csv")
a.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   NaN
# 1       10.34  1.66    Male     No  NaN  Dinner   3.0
# 2       21.01  3.50     NaN    NaN  Sun  Dinner   3.0
# 3         NaN  3.31     NaN     No  Sun  Dinner   2.0
# 4       24.59  3.61  Female     No  NaN  Dinner   4.0

# %%
a.isnull().sum()
# Out:
# total_bill    4
# tip           2
# sex           5
# smoker        3
# day           3
# time          2
# size          3
# dtype: int64

# %%
a['size']=a['size'].fillna(0)
a.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
a.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0

# %%
mn=a['total_bill'].mean()
mn
# Out:
# 19.47754098360656

# %%
md=a['sex'].mode()[0]
md
# Out:
# 'Male'

# %%
mdn=a['size'].median()
mdn
# Out:
# 2.0

# %%
a.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.477541    2.982705    2.545082
# std      9.241398    1.406192    0.990706
# min      0.000000    0.000000    0.000000
# 25%     13.105000    2.000000    2.000000
# 50%     17.550000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns
sns.countplot(x='sex',hue='day',data=a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import seaborn as sns
# ----> 2 sns.countplot(x='sex',hue='day',data=a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# # UNIVARIANT ANALYSIS

# %%
sns.countplot(data=a,x=a['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=a,x=a['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=a,x=a['day'])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data=a,x=a['time'])
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %% [markdown]
# # OBSERVATION
# ### 1.male is more than female
# ### 2. customers wanted to have dinner comparing to lunch
# ### 3. more customers in sat&sun comapring to other days
# ### 4. smokers are lesser than non-smokers
# ### 5. less customers in friday comparing to other days

# %%
sns.scatterplot(data=a,x="day",y="tip",hue="day",legend=True,palette="muted")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(data=a,x="day",y="tip",hue="day",legend=True,palette="muted")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(data=a,x="day",y="tip",hue="day",legend=True,palette="muted")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
a=a.select_dtypes(include=["number"])
sns.heatmap(a.corr(),annot=True,cmap="Greens")
# Out:
# <Axes: >
